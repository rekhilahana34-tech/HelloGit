# %%
hello hana
# Out:
#   Cell In[1], line 1
#     hello hana
#           ^
# SyntaxError: invalid syntax

# %%
print "hanna"
# Out:
#   Cell In[2], line 1
#     print "hanna"
#     ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print(...)?

# %%
print("hanna")
# Out:
# hanna
